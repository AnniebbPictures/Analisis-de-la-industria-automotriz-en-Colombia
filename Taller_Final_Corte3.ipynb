# %% [markdown]
# ## Taller Final - Corte 3: De los Datos Crudos al Insight Gerencial
# ### Sector: Industria Automotriz
# #### Grupo 2: Juanita Merchán y Annie Bonilla

# %%
# Instalación de librerías necesarias
# %pip install pandas openpyxl

# Asegurar que el pip esté actualizado
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pandas in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Requirement already satisfied: openpyxl in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pip in c:\users\annie\appdata\local\programs\python\python313\lib\site-packages (25.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar la librería pandas
import pandas as pd
import numpy as np

# Cargar el archivo tabla1_emc_general.xlsx
df_general = pd.read_excel('tabla1_emc_general.xlsx')

# Cargar el archivo tabla2_emc_vehiculos.xlsx
df_vehiculos = pd.read_excel('tabla2_emc_vehiculos.xlsx')

# Cargar el archivo tabla3_demografia_censo2018.xlsx
df_demografia = pd.read_excel('tabla3_demografia_censo2018.xlsx')

# Mostrar las primeras filas para verificar
print("Datos de tabla1_emc_general.xlsx:")
print(df_general.head())
print("\n")
print("\nDatos de tabla2_emc_vehiculos.xlsx:")
print(df_vehiculos.head())
print("\n")
print("\nDatos de tabla3_demografia_censo2018.xlsx:")
print(df_demografia.head())
print("\n")
# Out:
# Datos de tabla1_emc_general.xlsx:
#   Unnamed: 0 Unnamed: 1                                          Antioquia  \
# 0        Año        Mes  Total comercio minorista y vehículos en el dep...
# 1        NaN        NaN                                                NaN
# 2        NaN        NaN                                                NaN
# 3       2025      Enero                                         123.665347
# 4        NaN    Febrero                                         120.511263
#
#                                           Unnamed: 3  \
# 0  Comercio, mantenimiento y reparación de vehícu...
# 1                                                NaN
# 2                 4511. Vehículos automotores nuevos
# 3                                         108.626431
# 4                                         126.738337
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1                                                NaN
# 2  4530- 4541. Partes, piezas (autopartes) y acce...
# 3                                         134.459701
# 4                                         130.970545
#
#                                           Unnamed: 5  \
# 0                             Comercio al por menor
# 1  Comercio al por menor en establecimientos espe...
# 2  4711 - 4719 - 4721 -4722 - 4723 - 4724 - 4729 ...
# 3                                         123.292346
# 4                                         118.826733
#
#                                           Unnamed: 6  \
# 0                                                NaN
# 1                                                NaN
# 2  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# 3                                         139.810596
# 4                                         127.039894
#
#                                           Unnamed: 7  \
# 0                                                NaN
# 1                                                NaN
# 2  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# 3                                         118.698212
# 4                                          94.837225
#
#                                           Unnamed: 8  \
# 0                                                NaN
# 1                                                NaN
# 2  4771 - 4772. Prendas de vestir y sus accesorio...
# 3                                         108.320114
# 4                                          87.849443
#
#                                           Unnamed: 9  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  4773. Productos farmacéuticos, medicinales, od...  ...
# 3                                         144.791796  ...
# 4                                         131.151392  ...
#
#                                          Unnamed: 54 Unnamed: 55  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  4773. Productos farmacéuticos, medicinales, od...         NaN
# 3                                         147.478574         NaN
# 4                                         140.099254         NaN
#
#                                  Otros departamentos  \
# 0  Total comercio minorista y vehículos en el dep...
# 1                                                NaN
# 2                                                NaN
# 3                                         123.049701
# 4                                         113.991154
#
#                                          Unnamed: 57  \
# 0  Comercio, mantenimiento y reparación de vehícu...
# 1                                                NaN
# 2                 4511. Vehículos automotores nuevos
# 3                                         110.331384
# 4                                         113.478661
#
#                                          Unnamed: 58  \
# 0                                                NaN
# 1                                                NaN
# 2  4530- 4541. Partes, piezas (autopartes) y acce...
# 3                                         138.061059
# 4                                         135.584995
#
#                                          Unnamed: 59  \
# 0                             Comercio al por menor
# 1  Comercio al por menor en establecimientos espe...
# 2  4711 - 4719 - 4721 -4722 - 4723 - 4724 - 4729 ...
# 3                                          121.41541
# 4                                          112.35687
#
#                                          Unnamed: 60  \
# 0                                                NaN
# 1                                                NaN
# 2  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# 3                                         143.688045
# 4                                         129.718159
#
#                                          Unnamed: 61  \
# 0                                                NaN
# 1                                                NaN
# 2  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# 3                                          144.49922
# 4                                         108.474957
#
#                                          Unnamed: 62  \
# 0                                                NaN
# 1                                                NaN
# 2  4771 - 4772. Prendas de vestir y sus accesorio...
# 3                                         100.651032
# 4                                          81.438478
#
#                                          Unnamed: 63
# 0                                                NaN
# 1                                                NaN
# 2  4773. Productos farmacéuticos, medicinales, od...
# 3                                         130.540544
# 4                                         107.829568
#
# [5 rows x 64 columns]
#
#
#
# Datos de tabla2_emc_vehiculos.xlsx:
#    Tipo de vehículo Unnamed: 1 Vehículos de origen nacional + importado  \
# 0               NaN        NaN                 Automóviles particulares
# 1               NaN        NaN                        Unidades vendidas
# 2            2025.0      Enero                                     3405
# 3               NaN    Febrero                                     4531
# 4               NaN      Marzo                                     4712
#
#      Unnamed: 3             Unnamed: 4    Unnamed: 5  \
# 0           NaN  Camperos y camionetas           NaN
# 1  Valor ventas      Unidades vendidas  Valor ventas
# 2     241201385                   9471    1181596926
# 3     307182298                   8910    1071946799
# 4     321924982                  10712    1262303106
#
#                       Unnamed: 6    Unnamed: 7          Unnamed: 8  \
# 0  Vehículos de transp. público            NaN  Vehículos de carga
# 1              Unidades vendidas  Valor ventas   Unidades vendidas
# 2                            553      82856022                1068
# 3                            487      64792361                1296
# 4                            492      60273624                1281
#
#      Unnamed: 9        Unnamed: 10   Unnamed: 11
# 0           NaN     Motocicletasa            NaN
# 1  Valor ventas  Unidades vendidas  Valor ventas
# 2     247300066              76268     531886954
# 3     233869642              83739     596627061
# 4     198738588              85762     604323891
#
#
#
# Datos de tabla3_demografia_censo2018.xlsx:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                               2018        NaN        NaN
# 1  Grupos de edad, departamento y Áreas  (Total, ...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                     Total Nacional      Total      Total
# 4                                                NaN        NaN      0 a 4
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN
# 1      Total       Sexo        NaN
# 2        NaN     Hombre      Mujer
# 3   44164417   21570493   22593924
# 4    3037781    1555605    1482176

# %% [markdown]
# #### Ingenieria de Datos con Python y Pandas

# %%
#Estandariza y limpia los nombres de columnas de un DataFrame para evitar problemas al manipularlos.
def clean_column_names(df):
    df = df.copy()
    df.columns = (
        df.columns.str.strip()
                    .str.lower()
                    .str.replace(" ", "_")
                    .str.replace("\n", "_")
                    .str.replace("(", "")
                    .str.replace(")", "")
    )
    return df


def convert_numeric_columns(df, cols):
    df = df.copy()
    for c in cols:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")
    return df


def summarize_missing(df):
    missing = df.isnull().sum()
    pct = (missing / len(df)) * 100
    return pd.DataFrame({"missing": missing, "missing_pct": pct})


def fill_missing_median(df):
    df = df.copy()
    num_cols = df.select_dtypes(include="number").columns
    for c in num_cols:
        df[c] = df[c].fillna(df[c].median())
    return df


def drop_constant_columns(df):
    nunique = df.nunique()
    const_cols = nunique[nunique <= 1].index.tolist()
    return df.drop(columns=const_cols), const_cols

# %% [markdown]
# ##### Base de datos 1: Informativos Comercio al por Menor - Por departamentos (EMC)

# %%
file_path = 'tabla1_emc_general.xlsx'

# Se lee el archivo Excel y se carga en un DataFrame de Pandas.
# El bloque 'try-except' es una buena práctica para manejar errores si el archivo no existe.
try:
    df1 = pd.read_excel(file_path)
    print("✅ Archivo 'tabla1_emc_general.xlsx' cargado exitosamente.")
except FileNotFoundError:
    print(f"❌ Error: No se encontró el archivo '{file_path}'. Asegúrate de que esté en la misma carpeta.")

# Mostramos las primeras 5 filas para tener una idea inicial de los datos.
print("\n--- Vista Previa de los Datos Crudos ('Sucios') ---")
df1.head()
# Out:
# ✅ Archivo 'tabla1_emc_general.xlsx' cargado exitosamente.
#
# --- Vista Previa de los Datos Crudos ('Sucios') ---
#   Unnamed: 0 Unnamed: 1                                          Antioquia  \
# 0        Año        Mes  Total comercio minorista y vehículos en el dep...
# 1        NaN        NaN                                                NaN
# 2        NaN        NaN                                                NaN
# 3       2025      Enero                                         123.665347
# 4        NaN    Febrero                                         120.511263
#
#                                           Unnamed: 3  \
# 0  Comercio, mantenimiento y reparación de vehícu...
# 1                                                NaN
# 2                 4511. Vehículos automotores nuevos
# 3                                         108.626431
# 4                                         126.738337
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1                                                NaN
# 2  4530- 4541. Partes, piezas (autopartes) y acce...
# 3                                         134.459701
# 4                                         130.970545
#
#                                           Unnamed: 5  \
# 0                             Comercio al por menor
# 1  Comercio al por menor en establecimientos espe...
# 2  4711 - 4719 - 4721 -4722 - 4723 - 4724 - 4729 ...
# 3                                         123.292346
# 4                                         118.826733
#
#                                           Unnamed: 6  \
# 0                                                NaN
# 1                                                NaN
# 2  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# 3                                         139.810596
# 4                                         127.039894
#
#                                           Unnamed: 7  \
# 0                                                NaN
# 1                                                NaN
# 2  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# 3                                         118.698212
# 4                                          94.837225
#
#                                           Unnamed: 8  \
# 0                                                NaN
# 1                                                NaN
# 2  4771 - 4772. Prendas de vestir y sus accesorio...
# 3                                         108.320114
# 4                                          87.849443
#
#                                           Unnamed: 9  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  4773. Productos farmacéuticos, medicinales, od...  ...
# 3                                         144.791796  ...
# 4                                         131.151392  ...
#
#                                          Unnamed: 54 Unnamed: 55  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  4773. Productos farmacéuticos, medicinales, od...         NaN
# 3                                         147.478574         NaN
# 4                                         140.099254         NaN
#
#                                  Otros departamentos  \
# 0  Total comercio minorista y vehículos en el dep...
# 1                                                NaN
# 2                                                NaN
# 3                                         123.049701
# 4                                         113.991154
#
#                                          Unnamed: 57  \
# 0  Comercio, mantenimiento y reparación de vehícu...
# 1                                                NaN
# 2                 4511. Vehículos automotores nuevos
# 3                                         110.331384
# 4                                         113.478661
#
#                                          Unnamed: 58  \
# 0                                                NaN
# 1                                                NaN
# 2  4530- 4541. Partes, piezas (autopartes) y acce...
# 3                                         138.061059
# 4                                         135.584995
#
#                                          Unnamed: 59  \
# 0                             Comercio al por menor
# 1  Comercio al por menor en establecimientos espe...
# 2  4711 - 4719 - 4721 -4722 - 4723 - 4724 - 4729 ...
# 3                                          121.41541
# 4                                          112.35687
#
#                                          Unnamed: 60  \
# 0                                                NaN
# 1                                                NaN
# 2  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# 3                                         143.688045
# 4                                         129.718159
#
#                                          Unnamed: 61  \
# 0                                                NaN
# 1                                                NaN
# 2  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# 3                                          144.49922
# 4                                         108.474957
#
#                                          Unnamed: 62  \
# 0                                                NaN
# 1                                                NaN
# 2  4771 - 4772. Prendas de vestir y sus accesorio...
# 3                                         100.651032
# 4                                          81.438478
#
#                                          Unnamed: 63
# 0                                                NaN
# 1                                                NaN
# 2  4773. Productos farmacéuticos, medicinales, od...
# 3                                         130.540544
# 4                                         107.829568
#
# [5 rows x 64 columns]

# %%
# Antes de limpiar, un buen analista siempre diagnostica el estado de los datos.

print("\n--- Diagnóstico Inicial del DataFrame ---")

# .info() nos da un resumen técnico: número de filas, columnas, tipos de datos y valores no nulos.
# Es la "radiografía" de nuestros datos.
print("1. Información General y Tipos de Datos:\n")

df1.info()

# .isnull().sum() nos dice exactamente cuántos valores nulos hay en cada columna.
print("\n2. Conteo de Valores Nulos por Columna:")
print(df1.isnull().sum())

# Creamos una copia del DataFrame para trabajar sobre ella, conservando el original.
# Esta es una práctica fundamental para no perder los datos crudos.
df1_clean = df1.copy()
df1_clean = df1_clean.round(3)
# Out:
# --- Diagnóstico Inicial del DataFrame ---
# 1. Información General y Tipos de Datos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           2 non-null      object
#  1   Unnamed: 1           10 non-null     object
#  2   Antioquia            10 non-null     object
#  3   Unnamed: 3           11 non-null     object
#  4   Unnamed: 4           10 non-null     object
#  5   Unnamed: 5           12 non-null     object
#  6   Unnamed: 6           10 non-null     object
#  7   Unnamed: 7           10 non-null     object
#  8   Unnamed: 8           10 non-null     object
#  9   Unnamed: 9           10 non-null     object
#  10  Unnamed: 10          0 non-null      float64
#  11  Atlántico            10 non-null     object
#  12  Unnamed: 12          11 non-null     object
#  13  Unnamed: 13          10 non-null     object
#  14  Unnamed: 14          12 non-null     object
#  15  Unnamed: 15          10 non-null     object
#  16  Unnamed: 16          10 non-null     object
#  17  Unnamed: 17          10 non-null     object
#  18  Unnamed: 18          10 non-null     object
#  19  Unnamed: 19          0 non-null      float64
#  20  Bogotá               10 non-null     object
#  21  Unnamed: 21          11 non-null     object
#  22  Unnamed: 22          10 non-null     object
#  23  Unnamed: 23          12 non-null     object
#  24  Unnamed: 24          10 non-null     object
#  25  Unnamed: 25          10 non-null     object
#  26  Unnamed: 26          10 non-null     object
#  27  Unnamed: 27          10 non-null     object
#  28  Unnamed: 28          0 non-null      float64
#  29  Cundinamarca         10 non-null     object
#  30  Unnamed: 30          11 non-null     object
#  31  Unnamed: 31          10 non-null     object
#  32  Unnamed: 32          12 non-null     object
#  33  Unnamed: 33          10 non-null     object
#  34  Unnamed: 34          10 non-null     object
#  35  Unnamed: 35          10 non-null     object
#  36  Unnamed: 36          10 non-null     object
#  37  Unnamed: 37          0 non-null      float64
#  38  Santander            10 non-null     object
#  39  Unnamed: 39          11 non-null     object
#  40  Unnamed: 40          10 non-null     object
#  41  Unnamed: 41          12 non-null     object
#  42  Unnamed: 42          10 non-null     object
#  43  Unnamed: 43          10 non-null     object
#  44  Unnamed: 44          10 non-null     object
#  45  Unnamed: 45          10 non-null     object
#  46  Unnamed: 46          0 non-null      float64
#  47  Valle del Cauca      10 non-null     object
#  48  Unnamed: 48          11 non-null     object
#  49  Unnamed: 49          10 non-null     object
#  50  Unnamed: 50          12 non-null     object
#  51  Unnamed: 51          10 non-null     object
#  52  Unnamed: 52          10 non-null     object
#  53  Unnamed: 53          10 non-null     object
#  54  Unnamed: 54          10 non-null     object
#  55  Unnamed: 55          0 non-null      float64
#  56  Otros departamentos  10 non-null     object
#  57  Unnamed: 57          11 non-null     object
#  58  Unnamed: 58          10 non-null     object
#  59  Unnamed: 59          12 non-null     object
#  60  Unnamed: 60          10 non-null     object
#  61  Unnamed: 61          10 non-null     object
#  62  Unnamed: 62          10 non-null     object
#  63  Unnamed: 63          10 non-null     object
# dtypes: float64(6), object(58)
# memory usage: 6.1+ KB
#
# 2. Conteo de Valores Nulos por Columna:
# Unnamed: 0     10
# Unnamed: 1      2
# Antioquia       2
# Unnamed: 3      1
# Unnamed: 4      2
#                ..
# Unnamed: 59     0
# Unnamed: 60     2
# Unnamed: 61     2
# Unnamed: 62     2
# Unnamed: 63     2
# Length: 64, dtype: int64

# %%
df1_clean = clean_column_names(df_general)

print("Shape original:", df_general.shape)
display(df1_clean.info())
display(df1_clean.describe(include="all").T)

print("\nDatos faltantes:")
display(summarize_missing(df1_clean).head(15))

# Quitar duplicados
df1_clean = df1_clean.drop_duplicates()

# Columnas constantes
df1_clean, const_cols = drop_constant_columns(df1_clean)
print("\nColumnas constantes eliminadas:", const_cols)

# Intento de detectar columnas de ventas
ventas_cols = [c for c in df1_clean.columns if "venta" in c or "valor" in c or "monto" in c]
print("\nColumnas de ventas detectadas:", ventas_cols)

df1_clean = convert_numeric_columns(df1_clean, ventas_cols)
df1_clean = fill_missing_median(df1_clean)

print("\nShape final tabla1:", df1_clean.shape)
display(df1.head())

def capitalizar_meses_df1_clean(df1_clean):
    meses = {
        'enero': 'Enero','febrero': 'Febrero','marzo': 'Marzo',
        'abril': 'Abril','mayo': 'Mayo','junio': 'Junio',
        'julio': 'Julio','agosto': 'Agosto','septiembre': 'Septiembre',
        'setiembre': 'Septiembre','octubre': 'Octubre',
        'noviembre': 'Noviembre','diciembre': 'Diciembre'
    }
    df1_clean['mes'] = df1_clean['mes'].str.strip().str.lower().map(meses)
    return df1_clean
# Out:
# Shape original: (12, 64)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   unnamed:_0           2 non-null      object
#  1   unnamed:_1           10 non-null     object
#  2   antioquia            10 non-null     object
#  3   unnamed:_3           11 non-null     object
#  4   unnamed:_4           10 non-null     object
#  5   unnamed:_5           12 non-null     object
#  6   unnamed:_6           10 non-null     object
#  7   unnamed:_7           10 non-null     object
#  8   unnamed:_8           10 non-null     object
#  9   unnamed:_9           10 non-null     object
#  10  unnamed:_10          0 non-null      float64
#  11  atlántico            10 non-null     object
#  12  unnamed:_12          11 non-null     object
#  13  unnamed:_13          10 non-null     object
#  14  unnamed:_14          12 non-null     object
#  15  unnamed:_15          10 non-null     object
#  16  unnamed:_16          10 non-null     object
#  17  unnamed:_17          10 non-null     object
#  18  unnamed:_18          10 non-null     object
#  19  unnamed:_19          0 non-null      float64
#  20  bogotá               10 non-null     object
#  21  unnamed:_21          11 non-null     object
#  22  unnamed:_22          10 non-null     object
#  23  unnamed:_23          12 non-null     object
#  24  unnamed:_24          10 non-null     object
#  25  unnamed:_25          10 non-null     object
#  26  unnamed:_26          10 non-null     object
#  27  unnamed:_27          10 non-null     object
#  28  unnamed:_28          0 non-null      float64
#  29  cundinamarca         10 non-null     object
#  30  unnamed:_30          11 non-null     object
#  31  unnamed:_31          10 non-null     object
#  32  unnamed:_32          12 non-null     object
#  33  unnamed:_33          10 non-null     object
#  34  unnamed:_34          10 non-null     object
#  35  unnamed:_35          10 non-null     object
#  36  unnamed:_36          10 non-null     object
#  37  unnamed:_37          0 non-null      float64
#  38  santander            10 non-null     object
#  39  unnamed:_39          11 non-null     object
#  40  unnamed:_40          10 non-null     object
#  41  unnamed:_41          12 non-null     object
#  42  unnamed:_42          10 non-null     object
#  43  unnamed:_43          10 non-null     object
#  44  unnamed:_44          10 non-null     object
#  45  unnamed:_45          10 non-null     object
#  46  unnamed:_46          0 non-null      float64
#  47  valle_del_cauca      10 non-null     object
#  48  unnamed:_48          11 non-null     object
#  49  unnamed:_49          10 non-null     object
#  50  unnamed:_50          12 non-null     object
#  51  unnamed:_51          10 non-null     object
#  52  unnamed:_52          10 non-null     object
#  53  unnamed:_53          10 non-null     object
#  54  unnamed:_54          10 non-null     object
#  55  unnamed:_55          0 non-null      float64
#  56  otros_departamentos  10 non-null     object
#  57  unnamed:_57          11 non-null     object
#  58  unnamed:_58          10 non-null     object
#  59  unnamed:_59          12 non-null     object
#  60  unnamed:_60          10 non-null     object
#  61  unnamed:_61          10 non-null     object
#  62  unnamed:_62          10 non-null     object
#  63  unnamed:_63          10 non-null     object
# dtypes: float64(6), object(58)
# memory usage: 6.1+ KB
# None
#             count unique                                                top  \
# unnamed:_0      2      2                                                Año
# unnamed:_1     10     10                                                Mes
# antioquia      10     10  Total comercio minorista y vehículos en el dep...
# unnamed:_3     11     11  Comercio, mantenimiento y reparación de vehícu...
# unnamed:_4     10     10  4530- 4541. Partes, piezas (autopartes) y acce...
# ...           ...    ...                                                ...
# unnamed:_59    12     12                             Comercio al por menor
# unnamed:_60    10     10  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# unnamed:_61    10     10  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# unnamed:_62    10     10  4771 - 4772. Prendas de vestir y sus accesorio...
# unnamed:_63    10     10  4773. Productos farmacéuticos, medicinales, od...
#
#             freq mean  std  min  25%  50%  75%  max
# unnamed:_0     1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_1     1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# antioquia      1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_3     1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_4     1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...          ...  ...  ...  ...  ...  ...  ...  ...
# unnamed:_59    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_60    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_61    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_62    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# unnamed:_63    1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [64 rows x 11 columns]
# Datos faltantes:
#              missing  missing_pct
# unnamed:_0        10    83.333333
# unnamed:_1         2    16.666667
# antioquia          2    16.666667
# unnamed:_3         1     8.333333
# unnamed:_4         2    16.666667
# unnamed:_5         0     0.000000
# unnamed:_6         2    16.666667
# unnamed:_7         2    16.666667
# unnamed:_8         2    16.666667
# unnamed:_9         2    16.666667
# unnamed:_10       12   100.000000
# atlántico          2    16.666667
# unnamed:_12        1     8.333333
# unnamed:_13        2    16.666667
# unnamed:_14        0     0.000000
# Columnas constantes eliminadas: ['unnamed:_10', 'unnamed:_19', 'unnamed:_28', 'unnamed:_37', 'unnamed:_46', 'unnamed:_55']
#
# Columnas de ventas detectadas: []
#
# Shape final tabla1: (12, 58)
#   Unnamed: 0 Unnamed: 1                                          Antioquia  \
# 0        Año        Mes  Total comercio minorista y vehículos en el dep...
# 1        NaN        NaN                                                NaN
# 2        NaN        NaN                                                NaN
# 3       2025      Enero                                         123.665347
# 4        NaN    Febrero                                         120.511263
#
#                                           Unnamed: 3  \
# 0  Comercio, mantenimiento y reparación de vehícu...
# 1                                                NaN
# 2                 4511. Vehículos automotores nuevos
# 3                                         108.626431
# 4                                         126.738337
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1                                                NaN
# 2  4530- 4541. Partes, piezas (autopartes) y acce...
# 3                                         134.459701
# 4                                         130.970545
#
#                                           Unnamed: 5  \
# 0                             Comercio al por menor
# 1  Comercio al por menor en establecimientos espe...
# 2  4711 - 4719 - 4721 -4722 - 4723 - 4724 - 4729 ...
# 3                                         123.292346
# 4                                         118.826733
#
#                                           Unnamed: 6  \
# 0                                                NaN
# 1                                                NaN
# 2  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# 3                                         139.810596
# 4                                         127.039894
#
#                                           Unnamed: 7  \
# 0                                                NaN
# 1                                                NaN
# 2  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# 3                                         118.698212
# 4                                          94.837225
#
#                                           Unnamed: 8  \
# 0                                                NaN
# 1                                                NaN
# 2  4771 - 4772. Prendas de vestir y sus accesorio...
# 3                                         108.320114
# 4                                          87.849443
#
#                                           Unnamed: 9  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  4773. Productos farmacéuticos, medicinales, od...  ...
# 3                                         144.791796  ...
# 4                                         131.151392  ...
#
#                                          Unnamed: 54 Unnamed: 55  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
# 2  4773. Productos farmacéuticos, medicinales, od...         NaN
# 3                                         147.478574         NaN
# 4                                         140.099254         NaN
#
#                                  Otros departamentos  \
# 0  Total comercio minorista y vehículos en el dep...
# 1                                                NaN
# 2                                                NaN
# 3                                         123.049701
# 4                                         113.991154
#
#                                          Unnamed: 57  \
# 0  Comercio, mantenimiento y reparación de vehícu...
# 1                                                NaN
# 2                 4511. Vehículos automotores nuevos
# 3                                         110.331384
# 4                                         113.478661
#
#                                          Unnamed: 58  \
# 0                                                NaN
# 1                                                NaN
# 2  4530- 4541. Partes, piezas (autopartes) y acce...
# 3                                         138.061059
# 4                                         135.584995
#
#                                          Unnamed: 59  \
# 0                             Comercio al por menor
# 1  Comercio al por menor en establecimientos espe...
# 2  4711 - 4719 - 4721 -4722 - 4723 - 4724 - 4729 ...
# 3                                          121.41541
# 4                                          112.35687
#
#                                          Unnamed: 60  \
# 0                                                NaN
# 1                                                NaN
# 2  4741 - 4742 - 4751 - 4752 - 4753 - 4754 - 4755...
# 3                                         143.688045
# 4                                         129.718159
#
#                                          Unnamed: 61  \
# 0                                                NaN
# 1                                                NaN
# 2  4761 - 4762 - . 4769 - 4774. Artículos cultura...
# 3                                          144.49922
# 4                                         108.474957
#
#                                          Unnamed: 62  \
# 0                                                NaN
# 1                                                NaN
# 2  4771 - 4772. Prendas de vestir y sus accesorio...
# 3                                         100.651032
# 4                                          81.438478
#
#                                          Unnamed: 63
# 0                                                NaN
# 1                                                NaN
# 2  4773. Productos farmacéuticos, medicinales, od...
# 3                                         130.540544
# 4                                         107.829568
#
# [5 rows x 64 columns]

# %% [markdown]
# ##### Base de datos 2: Informativos Comercio de Vehículos - Por departamentos (EMC)

# %%
file_path2 = 'tabla2_emc_vehiculos.xlsx'

# Se lee el archivo Excel y se carga en un DataFrame de Pandas.
# El bloque 'try-except' es una buena práctica para manejar errores si el archivo no existe.
try:
    df2 = pd.read_excel(file_path2)
    print("✅ Archivo 'tabla2_emc_vehiculos.xlsx' cargado exitosamente.")
except FileNotFoundError:
    print(f"❌ Error: No se encontró el archivo '{file_path2}'. Asegúrate de que esté en la misma carpeta.")

# Mostramos las primeras 5 filas para tener una idea inicial de los datos.
print("\n--- Vista Previa de los Datos Crudos ('Sucios') ---")
df2.head()
# Out:
# ✅ Archivo 'tabla2_emc_vehiculos.xlsx' cargado exitosamente.
#
# --- Vista Previa de los Datos Crudos ('Sucios') ---
#    Tipo de vehículo Unnamed: 1 Vehículos de origen nacional + importado  \
# 0               NaN        NaN                 Automóviles particulares
# 1               NaN        NaN                        Unidades vendidas
# 2            2025.0      Enero                                     3405
# 3               NaN    Febrero                                     4531
# 4               NaN      Marzo                                     4712
#
#      Unnamed: 3             Unnamed: 4    Unnamed: 5  \
# 0           NaN  Camperos y camionetas           NaN
# 1  Valor ventas      Unidades vendidas  Valor ventas
# 2     241201385                   9471    1181596926
# 3     307182298                   8910    1071946799
# 4     321924982                  10712    1262303106
#
#                       Unnamed: 6    Unnamed: 7          Unnamed: 8  \
# 0  Vehículos de transp. público            NaN  Vehículos de carga
# 1              Unidades vendidas  Valor ventas   Unidades vendidas
# 2                            553      82856022                1068
# 3                            487      64792361                1296
# 4                            492      60273624                1281
#
#      Unnamed: 9        Unnamed: 10   Unnamed: 11
# 0           NaN     Motocicletasa            NaN
# 1  Valor ventas  Unidades vendidas  Valor ventas
# 2     247300066              76268     531886954
# 3     233869642              83739     596627061
# 4     198738588              85762     604323891

# %%
# Antes de limpiar, un buen analista siempre diagnostica el estado de los datos.

print("\n--- Diagnóstico Inicial del DataFrame ---")

# .info() nos da un resumen técnico: número de filas, columnas, tipos de datos y valores no nulos.
# Es la "radiografía" de nuestros datos.
print("1. Información General y Tipos de Datos:\n")

df2.info()

# .isnull().sum() nos dice exactamente cuántos valores nulos hay en cada columna.
print("\n2. Conteo de Valores Nulos por Columna:")
print(df2.isnull().sum())

# Creamos una copia del DataFrame para trabajar sobre ella, conservando el original.
# Esta es una práctica fundamental para no perder los datos crudos.
df2_clean = df2.copy()
df2_clean = df2_clean.round(3)


# Retirar mayusculas para facilitar el acceso al proceso de finaniciación
def capitalizar_meses_df2_clean(df2_clean):
    meses = {
        'enero': 'Enero','febrero': 'Febrero','marzo': 'Marzo',
        'abril': 'Abril','mayo': 'Mayo','junio': 'Junio',
        'julio': 'Julio','agosto': 'Agosto','septiembre': 'Septiembre',
        'setiembre': 'Septiembre','octubre': 'Octubre',
        'noviembre': 'Noviembre','diciembre': 'Diciembre'
    }
# Out:
# --- Diagnóstico Inicial del DataFrame ---
# 1. Información General y Tipos de Datos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Tipo de vehículo                          1 non-null      float64
#  1   Unnamed: 1                                9 non-null      object
#  2   Vehículos de origen nacional + importado  11 non-null     object
#  3   Unnamed: 3                                10 non-null     object
#  4   Unnamed: 4                                11 non-null     object
#  5   Unnamed: 5                                10 non-null     object
#  6   Unnamed: 6                                11 non-null     object
#  7   Unnamed: 7                                10 non-null     object
#  8   Unnamed: 8                                11 non-null     object
#  9   Unnamed: 9                                10 non-null     object
#  10  Unnamed: 10                               11 non-null     object
#  11  Unnamed: 11                               10 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 1.2+ KB
#
# 2. Conteo de Valores Nulos por Columna:
# Tipo de vehículo                            10
# Unnamed: 1                                   2
# Vehículos de origen nacional + importado     0
# Unnamed: 3                                   1
# Unnamed: 4                                   0
# Unnamed: 5                                   1
# Unnamed: 6                                   0
# Unnamed: 7                                   1
# Unnamed: 8                                   0
# Unnamed: 9                                   1
# Unnamed: 10                                  0
# Unnamed: 11                                  1
# dtype: int64

# %%
df2_clean = clean_column_names(df_vehiculos)

print("Shape original:", df_vehiculos.shape)
display(df2_clean.info())
display(df2_clean.describe(include="all").T)
display(summarize_missing(df2_clean).head(20))

# Convertir fechas si existen
for c in df2_clean.columns:
    if "fecha" in c or "anio" in c:
        df2_clean[c] = pd.to_datetime(df2_clean[c], errors="coerce")

# Normalización de localización
loc_cols = [c for c in df2_clean.columns if "depart" in c or "ciudad" in c]
for c in loc_cols:
    df2_clean[c] = df2_clean[c].astype(str).str.strip().str.title()

# Columnas numéricas importantes
num_cols = [c for c in df2_clean.columns if "venta" in c or "cantidad" in c or "valor" in c]
df2_clean = convert_numeric_columns(df2_clean, num_cols)

# Llenar NA
df2_clean = fill_missing_median(df2_clean)

# Quitar duplicados
df2_clean = df2_clean.drop_duplicates()

print("\nShape final tabla2:", df2_clean.shape)
display(df2_clean.head())
# Out:
# Shape original: (11, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 12 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   tipo_de_vehículo                          1 non-null      float64
#  1   unnamed:_1                                9 non-null      object
#  2   vehículos_de_origen_nacional_+_importado  11 non-null     object
#  3   unnamed:_3                                10 non-null     object
#  4   unnamed:_4                                11 non-null     object
#  5   unnamed:_5                                10 non-null     object
#  6   unnamed:_6                                11 non-null     object
#  7   unnamed:_7                                10 non-null     object
#  8   unnamed:_8                                11 non-null     object
#  9   unnamed:_9                                10 non-null     object
#  10  unnamed:_10                               11 non-null     object
#  11  unnamed:_11                               10 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 1.2+ KB
# None
#                                          count unique  \
# tipo_de_vehículo                           1.0    NaN
# unnamed:_1                                   9      9
# vehículos_de_origen_nacional_+_importado    11     11
# unnamed:_3                                  10     10
# unnamed:_4                                  11     11
# unnamed:_5                                  10     10
# unnamed:_6                                  11     11
# unnamed:_7                                  10     10
# unnamed:_8                                  11     11
# unnamed:_9                                  10     10
# unnamed:_10                                 11     11
# unnamed:_11                                 10     10
#
#                                                                     top freq  \
# tipo_de_vehículo                                                    NaN  NaN
# unnamed:_1                                                        Enero    1
# vehículos_de_origen_nacional_+_importado       Automóviles particulares    1
# unnamed:_3                                                 Valor ventas    1
# unnamed:_4                                        Camperos y camionetas    1
# unnamed:_5                                                 Valor ventas    1
# unnamed:_6                                Vehículos de transp. público     1
# unnamed:_7                                                 Valor ventas    1
# unnamed:_8                                           Vehículos de carga    1
# unnamed:_9                                                 Valor ventas    1
# unnamed:_10                                              Motocicletasa     1
# unnamed:_11                                                Valor ventas    1
#
#                                             mean  std     min     25%     50%  \
# tipo_de_vehículo                          2025.0  NaN  2025.0  2025.0  2025.0
# unnamed:_1                                   NaN  NaN     NaN     NaN     NaN
# vehículos_de_origen_nacional_+_importado     NaN  NaN     NaN     NaN     NaN
# unnamed:_3                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_4                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_5                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_6                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_7                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_8                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_9                                   NaN  NaN     NaN     NaN     NaN
# unnamed:_10                                  NaN  NaN     NaN     NaN     NaN
# unnamed:_11                                  NaN  NaN     NaN     NaN     NaN
#
#                                              75%     max
# tipo_de_vehículo                          2025.0  2025.0
# unnamed:_1                                   NaN     NaN
# vehículos_de_origen_nacional_+_importado     NaN     NaN
# unnamed:_3                                   NaN     NaN
# unnamed:_4                                   NaN     NaN
# unnamed:_5                                   NaN     NaN
# unnamed:_6                                   NaN     NaN
# unnamed:_7                                   NaN     NaN
# unnamed:_8                                   NaN     NaN
# unnamed:_9                                   NaN     NaN
# unnamed:_10                                  NaN     NaN
# unnamed:_11                                  NaN     NaN
#                                           missing  missing_pct
# tipo_de_vehículo                               10    90.909091
# unnamed:_1                                      2    18.181818
# vehículos_de_origen_nacional_+_importado        0     0.000000
# unnamed:_3                                      1     9.090909
# unnamed:_4                                      0     0.000000
# unnamed:_5                                      1     9.090909
# unnamed:_6                                      0     0.000000
# unnamed:_7                                      1     9.090909
# unnamed:_8                                      0     0.000000
# unnamed:_9                                      1     9.090909
# unnamed:_10                                     0     0.000000
# unnamed:_11                                     1     9.090909
# Shape final tabla2: (11, 12)
#    tipo_de_vehículo unnamed:_1 vehículos_de_origen_nacional_+_importado  \
# 0            2025.0        NaN                 Automóviles particulares
# 1            2025.0        NaN                        Unidades vendidas
# 2            2025.0      Enero                                     3405
# 3            2025.0    Febrero                                     4531
# 4            2025.0      Marzo                                     4712
#
#      unnamed:_3             unnamed:_4    unnamed:_5  \
# 0           NaN  Camperos y camionetas           NaN
# 1  Valor ventas      Unidades vendidas  Valor ventas
# 2     241201385                   9471    1181596926
# 3     307182298                   8910    1071946799
# 4     321924982                  10712    1262303106
#
#                       unnamed:_6    unnamed:_7          unnamed:_8  \
# 0  Vehículos de transp. público            NaN  Vehículos de carga
# 1              Unidades vendidas  Valor ventas   Unidades vendidas
# 2                            553      82856022                1068
# 3                            487      64792361                1296
# 4                            492      60273624                1281
#
#      unnamed:_9        unnamed:_10   unnamed:_11
# 0           NaN     Motocicletasa            NaN
# 1  Valor ventas  Unidades vendidas  Valor ventas
# 2     247300066              76268     531886954
# 3     233869642              83739     596627061
# 4     198738588              85762     604323891

# %% [markdown]
# ##### Base de datos 3: PERSONAS (Demográfico)

# %%
file_path3 = 'tabla3_demografia_censo2018.xlsx'

# Se lee el archivo Excel y se carga en un DataFrame de Pandas.
# El bloque 'try-except' es una buena práctica para manejar errores si el archivo no existe.
try:
    df3 = pd.read_excel(file_path3)
    print("✅ Archivo 'tabla3_demografia_censo2018.xlsx' cargado exitosamente.")
except FileNotFoundError:
    print(f"❌ Error: No se encontró el archivo '{file_path3}'. Asegúrate de que esté en la misma carpeta.")

# Mostramos las primeras 5 filas para tener una idea inicial de los datos.
print("\n--- Vista Previa de los Datos Crudos ('Sucios') ---")
df3.head()
# Out:
# ✅ Archivo 'tabla3_demografia_censo2018.xlsx' cargado exitosamente.
#
# --- Vista Previa de los Datos Crudos ('Sucios') ---
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                               2018        NaN        NaN
# 1  Grupos de edad, departamento y Áreas  (Total, ...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                     Total Nacional      Total      Total
# 4                                                NaN        NaN      0 a 4
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN
# 1      Total       Sexo        NaN
# 2        NaN     Hombre      Mujer
# 3   44164417   21570493   22593924
# 4    3037781    1555605    1482176

# %%
# Antes de limpiar, un buen analista siempre diagnostica el estado de los datos.

print("\n--- Diagnóstico Inicial del DataFrame ---")

# .info() nos da un resumen técnico: número de filas, columnas, tipos de datos y valores no nulos.
# Es la "radiografía" de nuestros datos.
print("1. Información General y Tipos de Datos:\n")

df3.info()

# .isnull().sum() nos dice exactamente cuántos valores nulos hay en cada columna.
print("\n2. Conteo de Valores Nulos por Columna:")
print(df3.isnull().sum())

# Creamos una copia del DataFrame para trabajar sobre ella, conservando el original.
# Esta es una práctica fundamental para no perder los datos crudos.
df3_clean = df3.copy()
df3_clean = df3_clean.round(3)
# Out:
# --- Diagnóstico Inicial del DataFrame ---
# 1. Información General y Tipos de Datos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2587 entries, 0 to 2586
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  36 non-null     object
#  1   Unnamed: 1  136 non-null    object
#  2   Unnamed: 2  2584 non-null   object
#  3   Unnamed: 3  2585 non-null   object
#  4   Unnamed: 4  2586 non-null   object
#  5   Unnamed: 5  2585 non-null   object
# dtypes: object(6)
# memory usage: 121.4+ KB
#
# 2. Conteo de Valores Nulos por Columna:
# Unnamed: 0    2551
# Unnamed: 1    2451
# Unnamed: 2       3
# Unnamed: 3       2
# Unnamed: 4       1
# Unnamed: 5       2
# dtype: int64

# %%
df3_clean = clean_column_names(df_demografia)

print("Shape original:", df_demografia.shape)
display(df3_clean.info())
display(df3_clean.describe(include="all").T)
display(summarize_missing(df3_clean).head(20))

# Convertir columnas a numéricas si son números disfrazados de texto
cols_to_convert = []
for c in df3_clean.columns:
    sample = df3_clean[c].dropna().astype(str).head(50)
    if sample.str.replace(",", "").str.replace(".", "").str.isnumeric().mean() > 0.4:
        cols_to_convert.append(c)

print("\nColumnas a convertir:", cols_to_convert)
df3_clean = convert_numeric_columns(df3_clean, cols_to_convert)

# Estandarizar ubicación
loc_cols = [c for c in df3_clean.columns if "depart" in c or "municip" in c]
for c in loc_cols:
    df3[c] = df3[c].astype(str).str.strip().str.title()

# Retirar mayusculas para facilitar el acceso al proceso de finaniciación
def capitalizar_meses_df3(df3):
    meses = {
        'enero': 'Enero','febrero': 'Febrero','marzo': 'Marzo',
        'abril': 'Abril','mayo': 'Mayo','junio': 'Junio',
        'julio': 'Julio','agosto': 'Agosto','septiembre': 'Septiembre',
        'setiembre': 'Septiembre','octubre': 'Octubre',
        'noviembre': 'Noviembre','diciembre': 'Diciembre'
    }
    df3['periodo'] = df3['periodo'].str.strip().str.lower().map(meses)
    return df3

# Llenar NA
df3_clean = fill_missing_median(df3_clean)

print("\nShape final tabla3:", df3_clean.shape)
display(df3_clean.head())
# Out:
# Shape original: (2587, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2587 entries, 0 to 2586
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   unnamed:_0  36 non-null     object
#  1   unnamed:_1  136 non-null    object
#  2   unnamed:_2  2584 non-null   object
#  3   unnamed:_3  2585 non-null   object
#  4   unnamed:_4  2586 non-null   object
#  5   unnamed:_5  2585 non-null   object
# dtypes: object(6)
# memory usage: 121.4+ KB
# None
#            count unique    top freq
# unnamed:_0    36     36   2018    1
# unnamed:_1   136      4  Total   34
# unnamed:_2  2584     19  Total  136
# unnamed:_3  2585   2448   1081    3
# unnamed:_4  2586   2345     22    6
# unnamed:_5  2585   2345     10    6
#             missing  missing_pct
# unnamed:_0     2551    98.608427
# unnamed:_1     2451    94.742945
# unnamed:_2        3     0.115964
# unnamed:_3        2     0.077310
# unnamed:_4        1     0.038655
# unnamed:_5        2     0.077310
# Columnas a convertir: ['unnamed:_3', 'unnamed:_4', 'unnamed:_5']
#
# Shape final tabla3: (2587, 6)
#                                           unnamed:_0 unnamed:_1 unnamed:_2  \
# 0                                               2018        NaN        NaN
# 1  Grupos de edad, departamento y Áreas  (Total, ...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                     Total Nacional      Total      Total
# 4                                                NaN        NaN      0 a 4
#
#    unnamed:_3  unnamed:_4  unnamed:_5
# 0     12270.5      6193.5      6259.5
# 1     12270.5      6193.5      6259.5
# 2     12270.5      6193.5      6259.5
# 3  44164417.0  21570493.0  22593924.0
# 4   3037781.0   1555605.0   1482176.0

# %%
# Exportar el Resultado

print("\n--- Iniciando Fase de Limpieza Final y Preparación para Exportación ---")

# Creamos una copia final para aplicar las últimas transformaciones.
# Es una buena práctica para no modificar el DataFrame anterior (df_clean).
df1_final = df1_clean.copy()
df2_final = df2_clean.copy()
df3_final = df3_clean.copy()

import os

# Exportar a Excel
output_filename = 'EMC_General_Limpio.xlsx'
df1_final.to_excel(output_filename, index=False)
output_filename2 = 'EMC_Vehiculos_Limpio.xlsx'
df2_final.to_excel(output_filename2, index=False)
output_filename3 = 'Demografia_Censo2018_Limpio.xlsx'
df3_final.to_excel(output_filename3, index=False)

print("✅ Archivos exportados exitosamente en formato Excel (.xlsx).")
# Out:
# --- Iniciando Fase de Limpieza Final y Preparación para Exportación ---
# ✅ Archivos exportados exitosamente en formato Excel (.xlsx).
